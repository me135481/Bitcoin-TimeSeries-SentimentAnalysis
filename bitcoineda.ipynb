# %%
path='/content/bitcoineda.csv'

# %%
import pandas as pd

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#     date  sentiment_scores  bitcoin_price
# 0  44232          0.129024    38144.30859
# 1  44233          0.138665    39266.01172
# 2  44234          0.138827    38903.44141
# 3  44235          0.154485    46196.46484
# 4  44236          0.151038    46481.10547

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.hist(df['sentiment_scores'], bins=20, edgecolor='black')
plt.xlabel('Sentiment Scores')
plt.ylabel('Frequency')
_ = plt.title('Distribution of Sentiment Scores')

# %%
from matplotlib import pyplot as plt
df['bitcoin_price'].plot(kind='line', figsize=(8, 4), title='bitcoin_price')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['sentiment_scores'].plot(kind='line', figsize=(8, 4), title='sentiment_scores')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title date

from matplotlib import pyplot as plt
df['date'].plot(kind='line', figsize=(8, 4), title='date')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.scatter(df['sentiment_scores'], df['bitcoin_price'])
plt.xlabel('Sentiment Scores')
plt.ylabel('Bitcoin Price')
_ = plt.title('Correlation: Bitcoin Price vs Sentiment')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['date']
  ys = series['bitcoin_price']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('date', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('date')
_ = plt.ylabel('bitcoin_price')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['date']
  ys = series['sentiment_scores']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('date', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('date')
_ = plt.ylabel('sentiment_scores')

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='sentiment_scores', y='bitcoin_price', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='date', y='sentiment_scores', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['bitcoin_price'].plot(kind='hist', bins=20, title='bitcoin_price')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title sentiment_scores

from matplotlib import pyplot as plt
df['sentiment_scores'].plot(kind='hist', bins=20, title='sentiment_scores')
plt.gca().spines[['top', 'right',]].set_visible(False)
